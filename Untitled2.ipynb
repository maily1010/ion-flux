# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('md1.xvg', sep='\s+',header=None, on_bad_lines='skip')
df
# Out:
#      0            1                           2       3         4        5  \
# 0    #         This                        file     was   created      Thu
# 1    #      Created                         by:     NaN       NaN      NaN
# 2    #          :-)                     GROMACS       -       gmx   mdrun,
# 3    #          NaN                         NaN     NaN       NaN      NaN
# 4    #  Executable:  /usr/local/gromacs/bin/gmx     NaN       NaN      NaN
# ..  ..          ...                         ...     ...       ...      ...
# 130  #         Atom                         nr.  217587  finished  passing
# 131  #        Solv.                   molecules      in   comp.A:    33417
# 132  #        Solv.                   molecules      in   comp.A:    33417
# 133  #         Atom                         nr.  217440  finished  passing
# 134  #         Atom                         nr.   59039  finished  passing
#
#              6      7         8     9
# ...
